# %%
#Import libraries
import pandas as pd 
import numpy as np
import os

# %%
#import data
df = pd.read_csv(r'C:\Users\msyeu\Instacart Basket Analysis\Data\Original Data\orders.csv', index_col = False)

# %%
#identifying path
path = r'C:\Users\msyeu\Instacart Basket Analysis'

# %%
#executing path
path
# Out:
# 'C:\\Users\\msyeu\\Instacart Basket Analysis'

# %%
#import orders data using os
df = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
# ommitting eval set using vars list 
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']
df = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'orders.csv'), usecols = vars_list)

# %%
#printing first 5 rows
df.head(5)
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# import products data using os
df_prods = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'products.csv'), index_col = False)

# %%
# print first 20 rows
df.head(20)
# Out:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1             1          2                  8
# 1    2398795        1             2          3                  7
# 2     473747        1             3          3                 12
# 3    2254736        1             4          4                  7
# 4     431534        1             5          4                 15
# 5    3367565        1             6          2                  7
# 6     550135        1             7          1                  9
# 7    3108588        1             8          1                 14
# 8    2295261        1             9          1                 16
# 9    2550362        1            10          4                  8
# 10   1187899        1            11          4                  8
# 11   2168274        2             1          2                 11
# 12   1501582        2             2          5                 10
# ...

# %%
#print last 35 rows
df.tail(35)
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 3421048    726186   206208            30          0                 16
# 3421049   2523609   206208            31          4                 11
# 3421050    756221   206208            32          6                 18
# 3421051   2254244   206208            33          6                 13
# 3421052   2017995   206208            34          6                 15
# 3421053   2789700   206208            35          3                 22
# 3421054    844592   206208            36          6                 15
# 3421055   1541132   206208            37          2                 12
# 3421056   2808240   206208            38          0                 15
# 3421057   3027766   206208            39          2                 14
# 3421058   3356245   206208            40          5                  9
# 3421059    442304   206208            41          2                 14
# ...

# %%
# print names of columns in products
df_prods.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices'], dtype='object')

# %%
#print number of rows and columns in products 
df_prods.shape
# Out:
# (49693, 5)

# %%
# maximum value of "aisle_id column"
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %% [markdown]
# Maximum value of aisle_id column is 134.000000

# %%
# data type of "department_id column"
df_prods.dtypes
# Out:
# product_id         int64
# product_name      object
# aisle_id           int64
# department_id      int64
# prices           float64
# dtype: object

# %% [markdown]
# Data type of department_id column is int64
