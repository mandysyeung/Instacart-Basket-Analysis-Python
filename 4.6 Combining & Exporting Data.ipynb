# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\msyeu\Instacart BAsket Analysis'

# %%
df_ords = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'orders_cleaned.csv'), index_col = False)

# %%
df_prods = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_ords_prior = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'orders_products_prior.csv'), index_col = False)

# %%
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0           0   2539329        1             1          2                  8
# 1           1   2398795        1             2          3                  7
# 2           2    473747        1             3          3                 12
# 3           3   2254736        1             4          4                  7
# 4           4    431534        1             5          4                 15
#
#    days_since_prior_order  first_order
# 0                     NaN         True
# 1                    15.0        False
# 2                    21.0        False
# 3                    29.0        False
# 4                    28.0        False

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number     order_dow  \
# count  2.525569e+06  2.525569e+06  2.525569e+06  2.525569e+06  2.525569e+06
# mean   1.262784e+06  1.710497e+06  7.593788e+04  1.718223e+01  2.777133e+00
# std    7.290691e+05  9.876746e+05  4.382872e+04  1.775107e+01  2.046110e+00
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    6.313920e+05  8.550450e+05  3.803000e+04  5.000000e+00  1.000000e+00
# 50%    1.262784e+06  1.709694e+06  7.591500e+04  1.100000e+01  3.000000e+00
# 75%    1.894176e+06  2.566332e+06  1.137050e+05  2.300000e+01  5.000000e+00
# max    2.525568e+06  3.421083e+06  1.520070e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       2.525569e+06            2.373562e+06
# mean        1.345669e+01            1.110364e+01
# std         4.226315e+00            9.202462e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# max         2.300000e+01            3.000000e+01

# %%
df_ords.shape
# Out:
# (2525569, 8)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods.describe()
# Out:
#          Unnamed: 0    product_id      aisle_id  department_id        prices
# count  49672.000000  49672.000000  49672.000000   49672.000000  49672.000000
# mean   24852.005053  24850.349775     67.762442      11.728942      9.993282
# std    14342.265579  14340.705287     38.315784       5.850779    453.615536
# min        0.000000      1.000000      1.000000       1.000000      1.000000
# 25%    12432.750000  12432.750000     35.000000       7.000000      4.100000
# 50%    24851.500000  24850.500000     69.000000      13.000000      7.100000
# 75%    37272.250000  37268.250000    100.000000      17.000000     11.100000
# max    49692.000000  49688.000000    134.000000      21.000000  99999.000000

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords_prior.describe()
# Out:
#            order_id    product_id  add_to_cart_order     reordered
# count  3.243449e+07  3.243449e+07       3.243449e+07  3.243449e+07
# mean   1.710749e+06  2.557634e+04       8.351076e+00  5.896975e-01
# std    9.873007e+05  1.409669e+04       7.126671e+00  4.918886e-01
# min    2.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.559430e+05  1.353000e+04       3.000000e+00  0.000000e+00
# 50%    1.711048e+06  2.525600e+04       6.000000e+00  1.000000e+00
# 75%    2.565514e+06  3.793500e+04       1.100000e+01  1.000000e+00
# max    3.421083e+06  4.968800e+04       1.450000e+02  1.000000e+00

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
#Export data to pkl
df_merged_large.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# # Step 4 - Check the output of Dataframes

# %%
df_orders_products_combined = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_orders_products_combined.shape
# Out:
# (23939847, 12)

# %% [markdown]
# # Step 5 - Determine a suitable way to combine orders_products_combined with products data set.

# %%
#Drop unnamed colums in df_prods
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0           0   2539329        1             1          2                  8
# 1           0   2539329        1             1          2                  8
# 2           0   2539329        1             1          2                  8
# 3           0   2539329        1             1          2                  8
# 4           0   2539329        1             1          2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# 4          0   both

# %%
df_orders_products_combined = df_orders_products_combined.drop(columns = ['Unnamed: 0', '_merge'])

# %%
df_orders_products_merged = df_orders_products_combined.merge(df_prods, on = 'product_id', indicator = True)

# %%
df_orders_products_merged.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda        77
# 1          0  Organic Unsweetened Vanilla Almond Milk        91
# 2          0                      Original Beef Jerky        23
# 3          0               Aged White Cheddar Popcorn        23
# 4          0         XL Pick-A-Size Paper Towel Rolls        54
#
#    department_id  prices _merge
# 0              7     9.0   both
# 1             16    12.5   both
# 2             19     4.4   both
# 3             19     4.7   both
# 4             17     1.0   both

# %% [markdown]
# # Step 6 - Confirm the results of the merge using the merge flag

# %%
df_orders_products_merged['_merge'].value_counts()
# Out:
# _merge
# both          23918195
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_orders_products_merged.shape
# Out:
# (23918195, 15)

# %%
#Export Data
df_orders_products_merged.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_merged.pkl'))
